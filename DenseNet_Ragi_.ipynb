# %% [markdown]
# ### **Implementation with DenseNet**

# %%
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# WARNING:tensorflow:From c:\Users\praj\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# **Seeding for reproducibility**

# %%
# Set seeds for reproducibility
import random
random.seed(0)

import numpy as np
np.random.seed(0)

import tensorflow as tf
tf.random.set_seed(0)

# %% [markdown]
# **Importing the dependencies**

# %%
# %pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\praj\appdata\local\programs\python\python310\lib\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\praj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\praj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\praj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\praj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\praj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\praj\appdata\roaming\python\python310\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\praj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\praj\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\praj\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\praj\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import json
from zipfile import ZipFile
from PIL import Image

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import layers, models

# %% [markdown]
# **Data Curation**

# %%
# Dataset Path
base_dir = r'C:\Users\praj\OneDrive\Desktop\Ragi Disease Detect\Data'

# %%
image_path = r'C:\Users\praj\OneDrive\Desktop\Ragi Disease Detect\Data\healthy\healthy (1).jpeg'

# Read the image
img = mpimg.imread(image_path)

print(img.shape)
# Display the image
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers
plt.show()
# Out:
# (159, 159, 3)

# %%
image_path = r'C:\Users\praj\OneDrive\Desktop\Ragi Disease Detect\Data\healthy\healthy (10).jpeg'

# Read the image
img = mpimg.imread(image_path)

print(img)
# Out:
# [[[ 92 103   7]
#   [ 92 103   7]
#   [ 89 103   5]
#   ...
#   [169 140  12]
#   [164 135   0]
#   [176 137   0]]
#
#  [[ 92 103   7]
#   [ 92 103   7]
#   [ 89 103   5]
#   ...
#   [166 139  10]
#   [165 137   2]
#   [175 135   1]]
#
#  [[ 93 105   7]
#   [ 93 105   7]
#   [ 90 104   6]
#   ...
#   [157 133   7]
#   [164 137   6]
#   [173 133   2]]
#
#  ...
#
#  [[100 119  11]
#   [ 99 119   8]
#   [ 97 117   4]
#   ...
#   [168 131   0]
#   [167 128   0]
#   [170 130   0]]
#
#  [[100 116   7]
#   [ 98 116   6]
#   [ 96 114   2]
#   ...
#   [168 129   0]
#   [168 128   0]
#   [172 129   0]]
#
#  [[104 113   4]
#   [101 113   1]
#   [100 114   1]
#   ...
#   [168 128   0]
#   [169 126   0]
#   [171 128   0]]]

# %%
# Image Parameters
img_size = 224
batch_size = 32

# %% [markdown]
# **Train Test Split**

# %%
# Image Data Generators
data_gen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # Use 20% of data for validation
)

# %%
# Train Generator
train_generator = data_gen.flow_from_directory(
    base_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    subset='training',
    class_mode='categorical'
)
# Out:
# Found 1212 images belonging to 6 classes.

# %%
# Validation Generator
validation_generator = data_gen.flow_from_directory(
    base_dir,
    target_size=(img_size, img_size),
    batch_size=batch_size,
    subset='validation',
    class_mode='categorical'
)
# Out:
# Found 301 images belonging to 6 classes.

# %% [markdown]
# **Convolutional Neural Network**

# %% [markdown]
# Implementing with DenseNet

# %%
# %pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\praj\appdata\local\programs\python\python310\lib\site-packages (1.15.3)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\users\praj\appdata\local\programs\python\python310\lib\site-packages (from scipy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras import models, layers, optimizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
img_size = 224  # Standard input size for DenseNet121
batch_size = 32

 # Standard input size for DenseNet121

# Load the DenseNet121 model without the top layers
base_model = DenseNet121(weights='imagenet', include_top=False, input_shape=(img_size, img_size, 3))

# Freeze the base model
base_model.trainable = False

# Create a new model on top
model = models.Sequential()
model.add(base_model)
model.add(layers.GlobalAveragePooling2D())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(512, activation='relu'))
model.add(layers.BatchNormalization())
model.add(layers.Dropout(0.5))
model.add(layers.Dense(train_generator.num_classes, activation='softmax'))

# Compile the model
model.compile(optimizer=optimizers.Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'] )
# Call model.build() or model.predict() on some dummy data to define input shape
# For example:
model.build((None, img_size, img_size, 3)) # Building the model with an explicit input shape

# Print the model summary


# Fine-tune the model
history = model.fit(train_generator,
    steps_per_epoch=train_generator.samples // batch_size,  # Number of steps per epoch
    epochs=100,  # Number of epochs
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size  # Validation steps
)
model.summary()
# Out:
# WARNING:tensorflow:From c:\Users\praj\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\praj\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Epoch 1/100
# WARNING:tensorflow:From c:\Users\praj\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\praj\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 37/37 [==============================] - 50s 1s/step - loss: 2.0631 - accuracy: 0.3407 - val_loss: 1.2686 - val_accuracy: 0.5694
# Epoch 2/100
# 37/37 [==============================] - 46s 1s/step - loss: 1.2661 - accuracy: 0.5602 - val_loss: 0.9040 - val_accuracy: 0.7188
# Epoch 3/100
# 37/37 [==============================] - 45s 1s/step - loss: 0.8395 - accuracy: 0.7059 - val_loss: 0.6966 - val_accuracy: 0.7743
# Epoch 4/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.7206 - accuracy: 0.7322 - val_loss: 0.5494 - val_accuracy: 0.8229
# Epoch 5/100
# 37/37 [==============================] - 42s 1s/step - loss: 0.5982 - accuracy: 0.7839 - val_loss: 0.4637 - val_accuracy: 0.8507
# Epoch 6/100
# 37/37 [==============================] - 51s 1s/step - loss: 0.5064 - accuracy: 0.8068 - val_loss: 0.3798 - val_accuracy: 0.8750
# Epoch 7/100
# 37/37 [==============================] - 47s 1s/step - loss: 0.4948 - accuracy: 0.8186 - val_loss: 0.3381 - val_accuracy: 0.8750
# Epoch 8/100
# 37/37 [==============================] - 46s 1s/step - loss: 0.3739 - accuracy: 0.8678 - val_loss: 0.3029 - val_accuracy: 0.8854
# Epoch 9/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.3274 - accuracy: 0.8890 - val_loss: 0.2960 - val_accuracy: 0.8854
# Epoch 10/100
# 37/37 [==============================] - 43s 1s/step - loss: 0.3639 - accuracy: 0.8712 - val_loss: 0.2638 - val_accuracy: 0.8958
# Epoch 11/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.3372 - accuracy: 0.8712 - val_loss: 0.2630 - val_accuracy: 0.8924
# Epoch 12/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.2570 - accuracy: 0.9008 - val_loss: 0.2361 - val_accuracy: 0.9062
# Epoch 13/100
# 37/37 [==============================] - 42s 1s/step - loss: 0.2471 - accuracy: 0.9169 - val_loss: 0.2052 - val_accuracy: 0.9167
# Epoch 14/100
# 37/37 [==============================] - 40s 1s/step - loss: 0.2465 - accuracy: 0.9068 - val_loss: 0.2053 - val_accuracy: 0.9236
# Epoch 15/100
# 37/37 [==============================] - 45s 1s/step - loss: 0.1902 - accuracy: 0.9280 - val_loss: 0.2107 - val_accuracy: 0.9167
# Epoch 16/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.2120 - accuracy: 0.9271 - val_loss: 0.2136 - val_accuracy: 0.9167
# Epoch 17/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.1959 - accuracy: 0.9390 - val_loss: 0.2134 - val_accuracy: 0.9236
# Epoch 18/100
# 37/37 [==============================] - 42s 1s/step - loss: 0.1702 - accuracy: 0.9364 - val_loss: 0.1951 - val_accuracy: 0.9236
# Epoch 19/100
# 37/37 [==============================] - 40s 1s/step - loss: 0.1919 - accuracy: 0.9288 - val_loss: 0.1736 - val_accuracy: 0.9444
# Epoch 20/100
# 37/37 [==============================] - 43s 1s/step - loss: 0.1630 - accuracy: 0.9458 - val_loss: 0.1902 - val_accuracy: 0.9201
# Epoch 21/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.1217 - accuracy: 0.9551 - val_loss: 0.1828 - val_accuracy: 0.9306
# Epoch 22/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.1670 - accuracy: 0.9390 - val_loss: 0.1714 - val_accuracy: 0.9340
# Epoch 23/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.1475 - accuracy: 0.9585 - val_loss: 0.1655 - val_accuracy: 0.9375
# Epoch 24/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.1348 - accuracy: 0.9500 - val_loss: 0.1752 - val_accuracy: 0.9236
# Epoch 25/100
# 37/37 [==============================] - 40s 1s/step - loss: 0.1377 - accuracy: 0.9483 - val_loss: 0.1601 - val_accuracy: 0.9340
# Epoch 26/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.1305 - accuracy: 0.9568 - val_loss: 0.1585 - val_accuracy: 0.9375
# Epoch 27/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.1030 - accuracy: 0.9636 - val_loss: 0.1600 - val_accuracy: 0.9444
# Epoch 28/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0979 - accuracy: 0.9644 - val_loss: 0.1439 - val_accuracy: 0.9444
# Epoch 29/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0973 - accuracy: 0.9678 - val_loss: 0.1563 - val_accuracy: 0.9375
# Epoch 30/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0831 - accuracy: 0.9712 - val_loss: 0.1344 - val_accuracy: 0.9514
# Epoch 31/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0956 - accuracy: 0.9695 - val_loss: 0.1503 - val_accuracy: 0.9444
# Epoch 32/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0695 - accuracy: 0.9771 - val_loss: 0.1456 - val_accuracy: 0.9479
# Epoch 33/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0801 - accuracy: 0.9729 - val_loss: 0.1492 - val_accuracy: 0.9375
# Epoch 34/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0849 - accuracy: 0.9678 - val_loss: 0.1395 - val_accuracy: 0.9479
# Epoch 35/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0774 - accuracy: 0.9746 - val_loss: 0.1407 - val_accuracy: 0.9479
# Epoch 36/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0904 - accuracy: 0.9661 - val_loss: 0.1445 - val_accuracy: 0.9549
# Epoch 37/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0696 - accuracy: 0.9780 - val_loss: 0.1478 - val_accuracy: 0.9514
# Epoch 38/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0842 - accuracy: 0.9720 - val_loss: 0.1497 - val_accuracy: 0.9444
# Epoch 39/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0722 - accuracy: 0.9763 - val_loss: 0.1374 - val_accuracy: 0.9653
# Epoch 40/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0785 - accuracy: 0.9720 - val_loss: 0.1387 - val_accuracy: 0.9583
# Epoch 41/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0683 - accuracy: 0.9780 - val_loss: 0.1481 - val_accuracy: 0.9479
# Epoch 42/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0559 - accuracy: 0.9831 - val_loss: 0.1313 - val_accuracy: 0.9549
# Epoch 43/100
# 37/37 [==============================] - 42s 1s/step - loss: 0.0785 - accuracy: 0.9737 - val_loss: 0.1457 - val_accuracy: 0.9444
# Epoch 44/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.0674 - accuracy: 0.9780 - val_loss: 0.1431 - val_accuracy: 0.9549
# Epoch 45/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0549 - accuracy: 0.9822 - val_loss: 0.1513 - val_accuracy: 0.9583
# Epoch 46/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0602 - accuracy: 0.9814 - val_loss: 0.1492 - val_accuracy: 0.9583
# Epoch 47/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0613 - accuracy: 0.9788 - val_loss: 0.1312 - val_accuracy: 0.9549
# Epoch 48/100
# 37/37 [==============================] - 40s 1s/step - loss: 0.0491 - accuracy: 0.9847 - val_loss: 0.1187 - val_accuracy: 0.9618
# Epoch 49/100
# 37/37 [==============================] - 40s 1s/step - loss: 0.0530 - accuracy: 0.9839 - val_loss: 0.1202 - val_accuracy: 0.9688
# Epoch 50/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0562 - accuracy: 0.9788 - val_loss: 0.1300 - val_accuracy: 0.9653
# Epoch 51/100
# 37/37 [==============================] - 43s 1s/step - loss: 0.0481 - accuracy: 0.9814 - val_loss: 0.1206 - val_accuracy: 0.9688
# Epoch 52/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.0703 - accuracy: 0.9822 - val_loss: 0.1118 - val_accuracy: 0.9688
# Epoch 53/100
# 37/37 [==============================] - 51s 1s/step - loss: 0.0704 - accuracy: 0.9729 - val_loss: 0.1176 - val_accuracy: 0.9757
# Epoch 54/100
# 37/37 [==============================] - 40s 1s/step - loss: 0.0527 - accuracy: 0.9814 - val_loss: 0.0960 - val_accuracy: 0.9757
# Epoch 55/100
# 37/37 [==============================] - 42s 1s/step - loss: 0.0464 - accuracy: 0.9856 - val_loss: 0.1185 - val_accuracy: 0.9653
# Epoch 56/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0513 - accuracy: 0.9805 - val_loss: 0.1361 - val_accuracy: 0.9583
# Epoch 57/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0390 - accuracy: 0.9856 - val_loss: 0.1411 - val_accuracy: 0.9583
# Epoch 58/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0555 - accuracy: 0.9864 - val_loss: 0.1033 - val_accuracy: 0.9653
# Epoch 59/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.0374 - accuracy: 0.9856 - val_loss: 0.0911 - val_accuracy: 0.9722
# Epoch 60/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0399 - accuracy: 0.9890 - val_loss: 0.1176 - val_accuracy: 0.9688
# Epoch 61/100
# 37/37 [==============================] - 40s 1s/step - loss: 0.0474 - accuracy: 0.9847 - val_loss: 0.1065 - val_accuracy: 0.9688
# Epoch 62/100
# 37/37 [==============================] - 40s 1s/step - loss: 0.0560 - accuracy: 0.9814 - val_loss: 0.0917 - val_accuracy: 0.9688
# Epoch 63/100
# 37/37 [==============================] - 44s 1s/step - loss: 0.0422 - accuracy: 0.9881 - val_loss: 0.1249 - val_accuracy: 0.9688
# Epoch 64/100
# 37/37 [==============================] - 43s 1s/step - loss: 0.0487 - accuracy: 0.9847 - val_loss: 0.1066 - val_accuracy: 0.9722
# Epoch 65/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0418 - accuracy: 0.9898 - val_loss: 0.1023 - val_accuracy: 0.9653
# Epoch 66/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0394 - accuracy: 0.9856 - val_loss: 0.1067 - val_accuracy: 0.9688
# Epoch 67/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0395 - accuracy: 0.9873 - val_loss: 0.0916 - val_accuracy: 0.9757
# Epoch 68/100
# 37/37 [==============================] - 46s 1s/step - loss: 0.0435 - accuracy: 0.9873 - val_loss: 0.1123 - val_accuracy: 0.9688
# Epoch 69/100
# 37/37 [==============================] - 47s 1s/step - loss: 0.0456 - accuracy: 0.9847 - val_loss: 0.1116 - val_accuracy: 0.9688
# Epoch 70/100
# 37/37 [==============================] - 44s 1s/step - loss: 0.0419 - accuracy: 0.9899 - val_loss: 0.0994 - val_accuracy: 0.9757
# Epoch 71/100
# 37/37 [==============================] - 44s 1s/step - loss: 0.0276 - accuracy: 0.9898 - val_loss: 0.1108 - val_accuracy: 0.9688
# Epoch 72/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.0491 - accuracy: 0.9856 - val_loss: 0.1259 - val_accuracy: 0.9653
# Epoch 73/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0373 - accuracy: 0.9856 - val_loss: 0.1451 - val_accuracy: 0.9583
# Epoch 74/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0323 - accuracy: 0.9864 - val_loss: 0.1344 - val_accuracy: 0.9618
# Epoch 75/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0392 - accuracy: 0.9856 - val_loss: 0.0967 - val_accuracy: 0.9722
# Epoch 76/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0380 - accuracy: 0.9881 - val_loss: 0.1087 - val_accuracy: 0.9618
# Epoch 77/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.0342 - accuracy: 0.9881 - val_loss: 0.1280 - val_accuracy: 0.9583
# Epoch 78/100
# 37/37 [==============================] - 46s 1s/step - loss: 0.0277 - accuracy: 0.9915 - val_loss: 0.1325 - val_accuracy: 0.9688
# Epoch 79/100
# 37/37 [==============================] - 43s 1s/step - loss: 0.0325 - accuracy: 0.9924 - val_loss: 0.1116 - val_accuracy: 0.9722
# Epoch 80/100
# 37/37 [==============================] - 44s 1s/step - loss: 0.0465 - accuracy: 0.9865 - val_loss: 0.1224 - val_accuracy: 0.9722
# Epoch 81/100
# 37/37 [==============================] - 44s 1s/step - loss: 0.0296 - accuracy: 0.9924 - val_loss: 0.1383 - val_accuracy: 0.9653
# Epoch 82/100
# 37/37 [==============================] - 44s 1s/step - loss: 0.0321 - accuracy: 0.9890 - val_loss: 0.1299 - val_accuracy: 0.9653
# Epoch 83/100
# 37/37 [==============================] - 40s 1s/step - loss: 0.0363 - accuracy: 0.9915 - val_loss: 0.1189 - val_accuracy: 0.9757
# Epoch 84/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0284 - accuracy: 0.9924 - val_loss: 0.1180 - val_accuracy: 0.9688
# Epoch 85/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0320 - accuracy: 0.9864 - val_loss: 0.1024 - val_accuracy: 0.9722
# Epoch 86/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0318 - accuracy: 0.9890 - val_loss: 0.1201 - val_accuracy: 0.9688
# Epoch 87/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0366 - accuracy: 0.9890 - val_loss: 0.0718 - val_accuracy: 0.9792
# Epoch 88/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0277 - accuracy: 0.9915 - val_loss: 0.1187 - val_accuracy: 0.9688
# Epoch 89/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.0236 - accuracy: 0.9941 - val_loss: 0.1201 - val_accuracy: 0.9653
# Epoch 90/100
# 37/37 [==============================] - 52s 1s/step - loss: 0.0291 - accuracy: 0.9898 - val_loss: 0.1091 - val_accuracy: 0.9653
# Epoch 91/100
# 37/37 [==============================] - 42s 1s/step - loss: 0.0334 - accuracy: 0.9890 - val_loss: 0.1206 - val_accuracy: 0.9688
# Epoch 92/100
# 37/37 [==============================] - 40s 1s/step - loss: 0.0345 - accuracy: 0.9890 - val_loss: 0.1162 - val_accuracy: 0.9653
# Epoch 93/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.0401 - accuracy: 0.9864 - val_loss: 0.1224 - val_accuracy: 0.9653
# Epoch 94/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.0416 - accuracy: 0.9873 - val_loss: 0.0963 - val_accuracy: 0.9722
# Epoch 95/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0423 - accuracy: 0.9847 - val_loss: 0.1235 - val_accuracy: 0.9653
# Epoch 96/100
# 37/37 [==============================] - 40s 1s/step - loss: 0.0336 - accuracy: 0.9898 - val_loss: 0.1186 - val_accuracy: 0.9722
# Epoch 97/100
# 37/37 [==============================] - 39s 1s/step - loss: 0.0213 - accuracy: 0.9958 - val_loss: 0.1093 - val_accuracy: 0.9722
# Epoch 98/100
# 37/37 [==============================] - 38s 1s/step - loss: 0.0306 - accuracy: 0.9890 - val_loss: 0.1235 - val_accuracy: 0.9757
# Epoch 99/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.0310 - accuracy: 0.9856 - val_loss: 0.0786 - val_accuracy: 0.9757
# Epoch 100/100
# 37/37 [==============================] - 41s 1s/step - loss: 0.0368 - accuracy: 0.9873 - val_loss: 0.1167 - val_accuracy: 0.9757
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet121 (Functional)    (None, 7, 7, 1024)        7037504
#
#  global_average_pooling2d (  (None, 1024)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 512)               524800
#
#  batch_normalization (Batch  (None, 512)               2048
#  Normalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  batch_normalization_1 (Bat  (None, 512)               2048
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 6)                 3078
#
# =================================================================
# Total params: 7832134 (29.88 MB)
# Trainable params: 792582 (3.02 MB)
# Non-trainable params: 7039552 (26.85 MB)
# _________________________________________________________________

# %%
# # Unfreeze the top layers of the base model
# for layer in base_model.layers[-10:]:
#     layer.trainable = True

# # Recompile the model with a lower learning rate for fine-tuning
# model.compile(optimizer=optimizers.Adam(learning_rate=1e-5),
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])


# # Fine-tune the model
# history = model.fit(
#     train_generator,
#     steps_per_epoch=train_generator.samples // batch_size,  # Number of steps per epoch
#     epochs=100,  # Number of epochs
#     validation_data=validation_generator,
#     validation_steps=validation_generator.samples // batch_size  # Validation steps
# )

# %% [markdown]
# **Model training**

# %% [markdown]
# **Model Evaluation**

# %%
# Model Evaluation
print("Evaluating model...")
val_loss, val_accuracy = model.evaluate(validation_generator, steps=validation_generator.samples // batch_size)
print(f"Validation Accuracy: {val_accuracy * 100:.2f}%")
# Out:
# Evaluating model...
# 9/9 [==============================] - 7s 809ms/step - loss: 0.1155 - accuracy: 0.9757
# Validation Accuracy: 97.57%

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# **Building a Predictive System**

# %%
# Function to Load and Preprocess the Image using Pillow
def load_and_preprocess_image(image_path, target_size=(224, 224)):
    # Load the image
    img = Image.open(image_path)
    # Resize the image
    img = img.resize(target_size)
    # Convert the image to a numpy array
    img_array = np.array(img)
    # Add batch dimension
    img_array = np.expand_dims(img_array, axis=0)
    # Scale the image values to [0, 1]
    img_array = img_array.astype('float32') / 255.
    return img_array

# Function to Predict the Class of an Image
def predict_image_class(model, image_path, class_indices):
    preprocessed_img = load_and_preprocess_image(image_path)
    predictions = model.predict(preprocessed_img)
    predicted_class_index = np.argmax(predictions, axis=1)[0]
    predicted_class_name = class_indices[predicted_class_index]
    return predicted_class_name

# %%
# Create a mapping from class indices to class names
class_indices = {v: k for k, v in train_generator.class_indices.items()}

# %%
class_indices
# Out:
# {0: 'downy', 1: 'healthy', 2: 'mottle', 3: 'seedling', 4: 'smut', 5: 'wilt'}

# %%
# saving the class names as json file
json.dump(class_indices, open('class_indices.json', 'w'))

# %%
# Example Usage
image_path = r'C:\Users\praj\OneDrive\Desktop\Ragi Disease Detect\Data\mottle\mottle_streak (6).jpg'
#image_path = '/content/test_blueberry_healthy.jpg'
#image_path = '/content/test_potato_early_blight.jpg'
predicted_class_name = predict_image_class(model, image_path, class_indices)

# Output the result
print("Predicted Class Name:", predicted_class_name)
# Out:
# 1/1 [==============================] - 3s 3s/step
# Predicted Class Name: mottle

# %% [markdown]
# **Save the model to Google drive or local**

# %%
model.save(r"C:\Users\praj\OneDrive\Desktop\RagiMilletCompleteDeployment\my_model")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\praj\OneDrive\Desktop\RagiMilletCompleteDeployment\my_model\assets
# INFO:tensorflow:Assets written to: C:\Users\praj\OneDrive\Desktop\RagiMilletCompleteDeployment\my_model\assets

# %%
model.save('ragirooga.h5')
# Out:
# c:\Users\praj\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt
import numpy as np

# Simulating accuracy values for three models across epochs
epochs = np.linspace(0, 100, 100)  # 100 epochs
accuracy_model1 = 96 * (1 - np.exp(-0.05 * epochs))  # DenseNet
accuracy_model2 = 88 * (1 - np.exp(-0.05 * epochs))  # VGG16
accuracy_model3 = 85 * (1 - np.exp(-0.05 * epochs))  # VGG19

# Plotting the line graph
plt.figure(figsize=(10, 6))
plt.plot(epochs, accuracy_model1, label='DenseNet (96%)', color='blue', linewidth=2)
plt.plot(epochs, accuracy_model2, label='VGG16 (88%)', color='green', linewidth=2)
plt.plot(epochs, accuracy_model3, label='VGG19 (85%)', color='red', linewidth=2)

# Adding titles and labels
plt.title('Model Accuracy vs. Number of Epochs', fontsize=16)
plt.xlabel('Number of Epochs', fontsize=14)
plt.ylabel('Model Accuracy (%)', fontsize=14)
plt.ylim(0, 100)
plt.xlim(0, 100)

# Adding grid and legend
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend(fontsize=12)

# Display the plot
plt.tight_layout()
plt.show()
